# %% [markdown]
# <a href="https://colab.research.google.com/github/LauraJDiaz/Ciencia-De-Datos/blob/main/actividad_28abril.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/titanic.csv')

# %%
#DataFrame de Titanic csv
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Cantidad de Nan por Feature
columna_nan_isna= df.isna().sum()
columna_nan_isna
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.sample(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 688          689         0       3
# 249          250         0       2
# 648          649         0       3
# 738          739         0       3
# 632          633         1       1
# 315          316         1       3
# 553          554         1       3
# 6              7         0       1
# 623          624         0       3
# 366          367         1       1
# 588          589         0       3
# 316          317         1       2
# 404          405         0       3
# 742          743         1       1
# 109          110         1       3
# 624          625         0       3
# 761          762         0       3
# 142          143         1       3
# 250          251         0       3
# 799          800         0       3
# 382          383         0       3
# 145          146         0       2
# 365          366         0       3
# 612          613         1       3
# ...

# %%
#Cantidad de NaN en total de DataFrame
total_nan_isna= df.isna().sum().sum()
total_nan_isna
# Out:
# np.int64(866)

# %%
#Quitar las filas que tengan los NaN
df_sin_nan = df[df['Age'].notna() & df['Cabin'].notna() & df['Embarked'].notna()]
df_sin_nan
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Reescribir los Age de float a int
df_sin_nan['Age']=df_sin_nan['Age'].astype(int)
df_sin_nan
# Out:
# <ipython-input-12-1716044e6d1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_nan['Age']=df_sin_nan['Age'].astype(int)
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# ...

# %%
def ggplot_survival_bar_colab(df_sin_nan):
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    ax = sns.countplot(x='Survived', data=datos, palette=["gray", "orange"])


    plt.title("Supervivencia")
    plt.xlabel("Survived")
    plt.ylabel("count")


    plt.legend(title="Survived", labels=["No", "Si"], loc="lower center", bbox_to_anchor=(0.5, -0.2), ncol=2)

    plt.show()


data = df_sin_nan['Survived']
datos = pd.DataFrame(data)

# 2. Apply the function
ggplot_survival_bar_colab(datos)
# Out:
# <ipython-input-13-477d9fc6b1b5>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Survived', data=datos, palette=["gray", "orange"])

# %%
def ggplot_survival_bar_colab(df):
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    ax = sns.countplot(x='Survived', data=datos, palette=["gray", "orange"])


    plt.title("Supervivencia")
    plt.xlabel("Survived")
    plt.ylabel("count")


    plt.legend(title="Survived", labels=["No", "Si"], loc="lower center", bbox_to_anchor=(0.5, -0.2), ncol=2)

    plt.show()


data = df['Survived']
datos = pd.DataFrame(data)

# 2. Apply the function
ggplot_survival_bar_colab(datos)
# Out:
# <ipython-input-14-c0f86473b8ea>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Survived', data=datos, palette=["gray", "orange"])

# %%
def ggplot_density_boxplot_colab(datos):
    sns.set_theme(style="whitegrid")
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    sns.kdeplot(data=datos, x='Age', hue='Survived', fill=True, alpha=0.5,
                palette=["gray", "orange"], ax=axes[0])
    sns.rugplot(data=datos, x='Age', hue='Survived', alpha=0.5,
                palette=["gray", "orange"], ax=axes[0])
    axes[0].set_title("Age")


    sns.boxplot(data=datos, x='Survived', y='Age', color='white',
                palette=["gray", "orange"], ax=axes[1])
    sns.stripplot(data=datos, x='Survived', y='Age', jitter=0.8, alpha=0.3,
                   palette=["gray", "orange"], ax=axes[1])
    axes[1].set_title("Age")

    fig.suptitle("Age", fontsize=16, y=1.02)


    axes[0].legend(title="Survived", labels=["No", "Si"], loc="upper right")
    axes[1].legend(title="Survived", labels=["No", "Si"], loc="upper right")

    plt.tight_layout()
    plt.show()


data = df_sin_nan[['Age', 'Survived']]
datos = pd.DataFrame(data)


ggplot_density_boxplot_colab(datos)

#Interpretación : Es más probable sobrevivir si tienes entre 20 y 40 años , específicamnte 35 , sin embargo si tenias mas de 65 años , era seguro que morias
# Out:
# <ipython-input-15-3a929b211322>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=datos, x='Survived', y='Age', color='white',
# <ipython-input-15-3a929b211322>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=datos, x='Survived', y='Age', jitter=0.8, alpha=0.3,

# %%
#Interpretación : Es más probable sobrevivir si tienes entre 20 y 40 años , específicamnte 35 , sin embargo si tenias mas de 65 años , era seguro que morias
plt.figure(figsize=(10,5))
sns.histplot(df_sin_nan['Age'].dropna(), bins=range(0,85,5), color='#55efc4', kde=True)
plt.title('¿Qué edades había en el Titanic?', pad=15)
plt.xlabel('Edad (años cumplidos)')
plt.ylabel('Cantidad de Pasajeros')
plt.axvline(df_sin_nan['Age'].median(), color='#e17055', linestyle='--')
plt.show()

# %%
def plot_learning_curve(estimator,title,X,y,xlim=None,cv=None,n_jobs=1,train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Ejemplos de entrenamiento")
    plt.ylabel("Puntuación de validación")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Puntuación de entrenamiento")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Puntuación de validación")

    plt.legend(loc="best")
    return plt

# %%
from IPython.display import Image

# %%
Image(url ="https://media.istockphoto.com/id/464771689/es/foto/transatl%C3%A1ntico.jpg?s=1024x1024&w=is&k=20&c=auaUkEyXypgP7izlgxY2MXYpr8hUopsProtGABAAi5A=")
# Out:
# <img src="https://media.istockphoto.com/id/464771689/es/foto/transatl%C3%A1ntico.jpg?s=1024x1024&w=is&k=20&c=auaUkEyXypgP7izlgxY2MXYpr8hUopsProtGABAAi5A="/>

# %%
#Diccionario de datos:
##Survive: 0= No sobrevio, 1= sobrevivio
## Sibsp = numero de hermanos/espeosos qeu ambrcaron
##Parch = numeros de padres/hijos que embarcaron
##Ticket: Numero de tiquete
## Embarked: puerto de embarcacion C=Cherbourg, Q=Queenstown, S=Southapton
# %matplotlib inline
sns.set()

# %%
def bar_char_with_percentage(feature, df):
    survived = df[df['Survived'] == 1][feature].value_counts()
    dead = df[df['Survived'] == 0][feature].value_counts()
    total = survived + dead

    survived_percentage = (survived / total) * 100
    dead_percentage = (dead / total) * 100

    test = pd.DataFrame([survived_percentage, dead_percentage])
    test.index = ["Survived", "Dead"]

    ax = test.plot(kind="bar", stacked=True, figsize=(10, 5))

    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy()
        ax.text(x + width/2,
                y + height/2,
                '{:.1f}%'.format(height),
                horizontalalignment='center',
                verticalalignment='center')

    plt.title(f'Sobrevivientes y Fallecidos por {feature} (Porcentaje)')
    plt.ylabel('Porcentaje')
    plt.xticks(rotation=0)
    plt.show()

# %%
#De la figura se concluye que las mujeres tuvieron mayor probabilidad de supervivencia.
bar_char_with_percentage('Sex', df)

# %%
#La grafica identifica que la clase 1 tuvo mayor chance de supervivencia en comparacion de las otras dos clases.
bar_char_with_percentage("Pclass",df)

# %%
#Los que tuvieron mayor probabilidad de sobrevivir si pertenecian a clase C
bar_char_with_percentage("Embarked",df)

# %%
bar_char_with_percentage("SibSp",df)

# %%
#De acuerdo al grafico, los sobrevivientes tenias al menos un hijo
bar_char_with_percentage("Parch",df)

# %% [markdown]
# #Ingenieria de las caracteristicas
# Es el eproceso de usar el dominio de conociiento de los datos para crear nuevas caracteristicas (feature vectors) con el fin de lograr qeu los algoritmos de machine learning funciones correctamente.
# Feature vectors son vectores de n-dimensiones que representan un objeto. Muchos algoritmos de ML requieren una representacion numerica de los objetivos, y aque tales representaciones facilitan el procesamiento y el analisis estaditicio.

# %% [markdown]
# ### Como se hundio el titanic?
# De acuerdo con lo conocido por la proa del barco, donde estaban las habitaciones de la tercera clase.
#
# Conclusion: Pclass es una feature

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def extract_title(data):
  title=data["Name"].str.extract('([A-Za-z]+)\.',expand=True)
  return title

# %%
df["Title"]=extract_title(df)

# %%
df["Title"].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
#investigar como se suman los str  (diccionarios probablemente)

# %% [markdown]
# ## Creando un mapeo de los titulos
# Reemplazamos los titulo enctrados por los soguientes valores
# * MR : 0
# * Miss:1
# * Mrs: 2
# * Otros: 3

# %%
def replace_titles(data):
  title_mapping= {"Mr":0, "Miss":1, "Mrs":2}
  data["Title"]= data["Title"].map(title_mapping).fillna(3)
  return data

# %%
df=replace_titles(df)
df[["Name","Title"]].head(20)
# Out:
#                                                  Name  Title
# 0                             Braund, Mr. Owen Harris    0.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    2.0
# 2                              Heikkinen, Miss. Laina    1.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    2.0
# 4                            Allen, Mr. William Henry    0.0
# 5                                    Moran, Mr. James    0.0
# 6                             McCarthy, Mr. Timothy J    0.0
# 7                      Palsson, Master. Gosta Leonard    3.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    2.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)    2.0
# 10                    Sandstrom, Miss. Marguerite Rut    1.0
# 11                           Bonnell, Miss. Elizabeth    1.0
# 12                     Saundercock, Mr. William Henry    0.0
# 13                        Andersson, Mr. Anders Johan    0.0
# ...

# %%
#Colocarle en vez de los numeros colocarle los nombres (toca no con la funcion sino cambiarlo en otro codigo)

# %%
bar_char_with_percentage("Title",df)

# %% [markdown]
# ##Edad
# ### Rellenar los NaN en edades
# Estrategia: Se calcula la media de los titulos y se reemplaza por las edades faltantes

# %%
title_age_means=df.groupby("Title")["Age"].mean()
title_age_means
# Out:
# Title
# 0.0    32.368090
# 1.0    21.773973
# 2.0    35.898148
# 3.0    20.430161
# Name: Age, dtype: float64

# %%
df["Age"]=df.apply( lambda row: title_age_means[row["Title"]] if pd.isnull(row["Age"]) else row["Age"], axis=1)

# %%
df[["Title","Age"]].sample(10)
# Out:
#      Title       Age
# 131    0.0  20.00000
# 598    0.0  32.36809
# 582    0.0  54.00000
# 884    0.0  25.00000
# 24     1.0   8.00000
# 228    0.0  18.00000
# 572    0.0  36.00000
# 620    0.0  27.00000
# 58     1.0   5.00000
# 40     2.0  40.00000

# %%
columna_nan_isna= df.isna().sum()
columna_nan_isna
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
#cambiar colores
#quitarle los NaN a las otras features

# %%
facet=sns.FacetGrid(df,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',fill=True)
facet.set(xlim=(0,df['Age'].max()))
facet.add_legend()
plt.show()

# %%
facet=sns.FacetGrid(df,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',fill=True)
facet.set(xlim=(0,df['Age'].max()))
facet.add_legend()
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# #Binning
# es convertir una variable numerica a cetegorica, en este caso, a edad

# %%
df["Age_Category"]=pd.cut(df["Age"],bins=[0,16,26,36,62,float("inf")], labels=["0-16","16-26","26-36","36-62","62+"], right=False)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title Age_Category
# 0      0         A/5 21171   7.2500   NaN        S    0.0        16-26
# 1      0          PC 17599  71.2833   C85        C    2.0        36-62
# 2      0  STON/O2. 3101282   7.9250   NaN        S    1.0        26-36
# ...

# %%
bar_char_with_percentage("Age_Category",df)

# %% [markdown]
# #Fare

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title',
#        'Age_Category'],
#       dtype='object')

# %%
facet=sns.FacetGrid(df,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',fill=True)
facet.set(xlim=(0,df['Fare'].max()))
facet.add_legend()
plt.show()

# %%
#La mayoria de los que murieron pagaron menos de 35, por otro laso practicamente todos los que pagaron mas de 50 tenian mucha mas probabilidad de sobrevivir.
facet=sns.FacetGrid(df,hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',fill=True)
facet.set(xlim=(0,df['Fare'].max()))
facet.add_legend()
plt.xlim(0,300)
# Out:
# (0.0, 300.0)

# %%
df["Fare_Category"]=pd.cut(df["Fare"],bins=[0,25,50,75,100,200,300,float("inf")], labels=["0-25","25-50","50-75","75-100","100-200","200-300","300+"], right=False)

# %%
#La probabilidad de mayor supervivencia era si pagaban mas de 75
bar_char_with_percentage("Fare_Category",df)

# %% [markdown]
# #Embarked

# %%
df[df['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Title  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN    1.0
# 829  female  62.0      0      0  113572  80.0   B28      NaN    2.0
#
#     Age_Category Fare_Category
# 61         36-62        75-100
# 829          62+        75-100

# %%
def extract_embarked_code(data):
  embarked_codes = data["Embarked"].str[0]
  return embarked_codes


df["Embarked_Code"] = extract_embarked_code(df)


df["Embarked_Code"].value_counts()
# Out:
# Embarked_Code
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title', 'Age_Category',
#        'Fare_Category', 'Embarked_Code'],
#       dtype='object')

# %%
def extract_class_1(data):
  class_codes = data['Pclass']==1
  return class_codes


df["class_1_code"] = extract_class_1(df)

df["class_1_code"].value_counts()
# Out:
# class_1_code
# False    675
# True     216
# Name: count, dtype: int64

# %%
#Como la mayoria de clase 1 entro por el puerto S , podriamos inferir que los dos NaN , los cuales son clase 1 , lo más probable es que entraran por el puerto S
clase_1 = df[df['Pclass'] == 1]


conteo_embarcados_clase1 = clase_1['Embarked_Code'].value_counts()

(conteo_embarcados_clase1)
# Out:
# Embarked_Code
# S    127
# C     85
# Q      2
# Name: count, dtype: int64

# %%
def replace_titles(data):
  title_mapping= {"S":0, "C":1, "Q":2}
  data["Title"]= data["Title"].map(title_mapping).fillna(3)
  return data

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
columna_nan_isna=df.isna().sum()
columna_nan_isna
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age                0
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin            687
# Embarked           0
# Title              0
# Age_Category       0
# Fare_Category      0
# Embarked_Code      2
# class_1_code       0
# dtype: int64

# %%
total_embarked = df['Embarked'].value_counts()


fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
axes = axes.flatten()


for i, embarked in enumerate(total_embarked.index):
    subset = df[df['Embarked'] == embarked]
    counts = subset['Survived'].value_counts(normalize=True) * 100
    ax = sns.barplot(x=counts.index, y=counts.values, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Puerto: {embarked}')
    axes[i].set_xlabel('Sobrevivió')
    axes[i].set_ylabel('Porcentaje')
    axes[i].set_xticks([0, 1])
    axes[i].set_xticklabels(['No', 'Sí'])
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x() + p.get_width() / 2., height + 1, f'{height:.1f}',
                ha='center', fontsize=10)

plt.suptitle('Porcentaje de Sobrevivientes por Puerto de Embarque', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-59-32632fc07769>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=counts.index, y=counts.values, ax=axes[i], palette='viridis')
# <ipython-input-59-32632fc07769>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=counts.index, y=counts.values, ax=axes[i], palette='viridis')
# <ipython-input-59-32632fc07769>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=counts.index, y=counts.values, ax=axes[i], palette='viridis')

# %% [markdown]
# ##Pregunta 1##

# %%
df.colums
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title', 'Age_Category',
#        'Fare_Category', 'Embarked_Code', 'class_1_code'],
#       dtype='object')

# %%
print("Total de registros:", df.shape[0])
sobrevivientes = df['Survived'].sum()
no_sobrevivientes = df.shape[0] - sobrevivientes
print("Sobrevivientes:", sobrevivientes)
print("No sobrevivientes:", no_sobrevivientes)
# Out:
# Total de registros: 891
# Sobrevivientes: 342
# No sobrevivientes: 549

# %%
tasa_supervivencia = df['Survived'].mean() * 100
print(f'Tasa global de supervivencia: {tasa_supervivencia:.2f}%')
# Out:
# Tasa global de supervivencia: 38.38%

# %%
survival_counts = df['Survived'].value_counts().sort_index()

# Gráfica
ax = sns.barplot(x=survival_counts.index, y=survival_counts.values, palette='Set2')

# Agregar etiquetas de porcentaje encima
total = survival_counts.sum()
for i, count in enumerate(survival_counts.values):
    porcentaje = 100 * count / total
    ax.text(i, count + 5, f'{porcentaje:.1f}%', ha='center', va='bottom', fontsize=12)

plt.xticks([0, 1], ['No sobrevivió', 'Sobrevivió'])
plt.title('Supervivencia Total')
plt.xlabel('Supervivencia')
plt.ylabel('Cantidad de pasajeros')
plt.show()
# Out:
# <ipython-input-70-63a465abf0da>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=survival_counts.index, y=survival_counts.values, palette='Set2')

# %% [markdown]
# ##Pregunta 2##

# %%
conteo_sexo = df['Sex'].value_counts()
(conteo_sexo)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
conteo_sexo_clase = df.groupby(['Pclass', 'Sex']).size().unstack()
(conteo_sexo_clase)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
conteo_sexo_clase.plot(kind='bar', stacked=True, color=['lightpink','lightblue'])
plt.title('Distribución de Hombres y Mujeres por Clase de Billete')
plt.xlabel('Clase de Billete')
plt.ylabel('Cantidad de Pasajeros')
plt.legend(title='Sexo')
plt.show()

# %% [markdown]
# ##Pregunta 3##

# %%
conteo_supervivencia_sexo = df.groupby(['Sex', 'Survived']).size().unstack()
(conteo_supervivencia_sexo)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
tasa_supervivencia_sexo = df.groupby('Sex')['Survived'].mean() * 100
(tasa_supervivencia_sexo)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
tasa_supervivencia_sexo.plot(kind='bar', color=['lightpink', 'lightblue'])
plt.title('Tasa de Supervivencia por Sexo (%)')
plt.xlabel('Sexo')
plt.ylabel('Tasa de Supervivencia (%)')
plt.ylim(0, 100)
plt.show()

# %%
ax = sns.countplot(data=df, x='Sex', hue='Survived', palette=['lightpink', 'lightblue'])

plt.title('Supervivencia por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Cantidad de pasajeros')

plt.legend(title='Sobrevivió', labels=['No', 'Sí'])

total = len(df)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.text(p.get_x() + p.get_width() / 2., height + 3, f'{percentage:.1f}%', ha="center")

plt.show()

# %% [markdown]
# ##Pregunta 4##

# %%
edad_disponible = df['Age'].notna().sum()
edad_faltante = df['Age'].isna().sum()
print("Edad disponible:", edad_disponible)
print("Edad faltante:", edad_faltante)
# Out:
# Edad disponible: 891
# Edad faltante: 0

# %%
sns.histplot(data=df, x='Age', bins=30, kde=True, color='skyblue')
plt.title('Distribución de Edad de los Pasajeros')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ##Pregunta 5##

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_Category', hue='Pclass', palette=['lightblue','lightpink', "orchid"])

plt.title('Distribución por Grupos de Edad por Clase de Billete')
plt.xlabel('Grupo de Edad')
plt.ylabel('Cantidad de Pasajeros')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_Category', hue='Sex', palette=['lightblue','lightpink'])

plt.title('Distribución por Grupos de Edad por Clase de Billete')
plt.xlabel('Grupo de Edad')
plt.ylabel('Cantidad de Pasajeros')
plt.show()

# %% [markdown]
# ##Pregunta 6##

# %% [markdown]
# ##Pregunta 7##

# %%
df['Family_Size'] = df['SibSp'] + df['Parch']
df['Travel_Group'] = df['Family_Size'].apply(lambda x: 'Solo' if x == 0 else 'Con Familia')

family_counts = df['Travel_Group'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(
    family_counts,
    labels=family_counts.index,
    autopct='%.1f%%',
    colors=['lightpink', 'lightblue'],
    startangle=90
)
plt.title("¿Viajaban solos o con familia?", fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(
    x='Family_Size',
    data=df,
    color=('lightpink'),
    order=sorted(df['Family_Size'].unique())
)
plt.title("Número de Familiares por Pasajero", fontweight='bold')
plt.xlabel("Número de Familiares (SibSp + Parch)")
plt.ylabel("Cantidad de Pasajeros")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##Pregunta 8##

# %% [markdown]
# En el siglo XX, una familia numerosa se consideraba generalmente como aquella con tres o más hijos.(De acuerdo al universal https://www.eluniversal.com.mx/tendencias/numerosas-asi-eran-las-familias-europeas-y-mexicanas/)

# %%
familias_numerosas = df[df['Family_Size'] >= 4]
clase_familias = familias_numerosas['Pclass'].value_counts().sort_index()

print("\n--- Familias Numerosas (más de 4 familiares) por Clase ---")
print(clase_familias)

plt.figure(figsize=(8, 4))
sns.countplot(x='Pclass', data=familias_numerosas, palette=['lightblue','lightpink', "orchid"])
plt.title('Familias Numerosas por Clase de Billete', fontweight='bold')
plt.xlabel('Clase (1 = Primera, 2 = Segunda, 3 = Tercera)')
plt.ylabel('Número de Familias')
plt.show()
# Out:
# --- Familias Numerosas (más de 4 familiares) por Clase ---
# Pclass
# 1     6
# 2     2
# 3    54
# Name: count, dtype: int64
# <ipython-input-161-17713f2b58b6>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=familias_numerosas, palette=['lightblue','lightpink', "orchid"])

# %%
mujeres_solas = df[(df['Sex'] == 'female') & (df['Family_Size'] == 0)]
prop_mujeres_solas = mujeres_solas['Pclass'].value_counts(normalize=True).sort_index() * 100

print("\n--- Proporción de Mujeres Solas por Clase (%) ---")
print(prop_mujeres_solas)

# Gráfico de pastel
plt.figure(figsize=(8, 6))
plt.pie(
    prop_mujeres_solas,
    labels=['Primera Clase', 'Segunda Clase', 'Tercera Clase'],
    autopct='%.1f%%',
    colors=['lightblue','lightpink', "orchid"],
    startangle=90
)
plt.title('Proporción de Mujeres Solas por Clase', fontweight='bold')
plt.show()
# Out:
# --- Proporción de Mujeres Solas por Clase (%) ---
# Pclass
# 1    26.984127
# 2    25.396825
# 3    47.619048
# Name: proportion, dtype: float64

# %%
grupo_billetes = df.groupby('Ticket').agg({
    'Fare': 'first',
    'PassengerId': 'count'
}).rename(columns={'PassengerId': 'Pasajeros'})

# 2. Calcular la tarifa individual por persona (Fare / Pasajeros)
grupo_billetes['Tarifa_Individual'] = grupo_billetes['Fare'] / grupo_billetes['Pasajeros']

# 3. Calcular la tarifa media por persona en todo el dataset
tarifa_media_por_persona = grupo_billetes['Tarifa_Individual'].mean()

print(f"\nTarifa media por persona: ${tarifa_media_por_persona:.2f}")
# Out:
# Tarifa media por persona: $16.75
